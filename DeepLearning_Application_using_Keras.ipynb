# %% [markdown]
# <a href="https://colab.research.google.com/github/vinitvshah/DeepLearning/blob/main/DeepLearning_Application_using_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pre-process Data

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load training data set from CSV file
training_data_df = pd.read_csv("sales_data_training.csv")

# Load testing data set from CSV file
test_data_df = pd.read_csv("sales_data_test.csv")

# Data needs to be scaled to a small range like 0 to 1 for the neural
# network to work well.
scaler = MinMaxScaler(feature_range=(0,1))

# Scale both the training inputs and outputs
scaled_training = scaler.fit_transform(training_data_df)
scaled_testing = scaler.transform(test_data_df)

# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: total_earnings values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[8], scaler.min_[8]))

# Create new pandas DataFrame objects from the scaled data
scaled_training_df = pd.DataFrame(scaled_training, columns=training_data_df.columns.values)
scaled_testing_df = pd.DataFrame(scaled_testing, columns=test_data_df.columns.values)

# Save scaled data dataframes to new CSV files
scaled_training_df.to_csv("sales_data_training_scaled.csv", index=False)
scaled_testing_df.to_csv("sales_data_test_scaled.csv", index=False)
# Out:
# Note: total_earnings values were scaled by multiplying by 0.0000036968 and adding -0.115913

# %% [markdown]
# Create Model

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import *

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Train Model - Smaller the error that is better

# %%
# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
# Out:
# Epoch 1/50
# 32/32 - 2s - loss: 0.0120 - 2s/epoch - 62ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 0.0018 - 80ms/epoch - 3ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 5.5672e-04 - 86ms/epoch - 3ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 3.5514e-04 - 89ms/epoch - 3ms/step
# Epoch 5/50
# 32/32 - 0s - loss: 2.2298e-04 - 88ms/epoch - 3ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 1.5457e-04 - 78ms/epoch - 2ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 1.2704e-04 - 80ms/epoch - 2ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 1.2478e-04 - 75ms/epoch - 2ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 9.7124e-05 - 76ms/epoch - 2ms/step
# Epoch 10/50
# 32/32 - 0s - loss: 7.1543e-05 - 81ms/epoch - 3ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 6.5684e-05 - 91ms/epoch - 3ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 7.1541e-05 - 82ms/epoch - 3ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 6.3897e-05 - 94ms/epoch - 3ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 5.0091e-05 - 98ms/epoch - 3ms/step
# Epoch 15/50
# 32/32 - 0s - loss: 5.5627e-05 - 105ms/epoch - 3ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 4.6973e-05 - 65ms/epoch - 2ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 5.9802e-05 - 76ms/epoch - 2ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 5.9894e-05 - 59ms/epoch - 2ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 5.8866e-05 - 59ms/epoch - 2ms/step
# Epoch 20/50
# 32/32 - 0s - loss: 4.7611e-05 - 53ms/epoch - 2ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 3.6048e-05 - 52ms/epoch - 2ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 3.7399e-05 - 62ms/epoch - 2ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 4.3201e-05 - 55ms/epoch - 2ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 3.5752e-05 - 58ms/epoch - 2ms/step
# Epoch 25/50
# 32/32 - 0s - loss: 3.7426e-05 - 55ms/epoch - 2ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 2.9232e-05 - 53ms/epoch - 2ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 3.4945e-05 - 69ms/epoch - 2ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 4.3012e-05 - 54ms/epoch - 2ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 3.1582e-05 - 63ms/epoch - 2ms/step
# Epoch 30/50
# 32/32 - 0s - loss: 3.0385e-05 - 54ms/epoch - 2ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 2.5461e-05 - 59ms/epoch - 2ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 4.9480e-05 - 73ms/epoch - 2ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 4.6668e-05 - 56ms/epoch - 2ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 4.3310e-05 - 60ms/epoch - 2ms/step
# Epoch 35/50
# 32/32 - 0s - loss: 3.4969e-05 - 59ms/epoch - 2ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 3.3042e-05 - 55ms/epoch - 2ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 2.3332e-05 - 58ms/epoch - 2ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 2.7211e-05 - 52ms/epoch - 2ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 2.5378e-05 - 61ms/epoch - 2ms/step
# Epoch 40/50
# 32/32 - 0s - loss: 3.8483e-05 - 55ms/epoch - 2ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 3.5424e-05 - 55ms/epoch - 2ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 2.8092e-05 - 61ms/epoch - 2ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 2.4345e-05 - 52ms/epoch - 2ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 5.4101e-05 - 55ms/epoch - 2ms/step
# Epoch 45/50
# 32/32 - 0s - loss: 8.6263e-05 - 59ms/epoch - 2ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 8.1020e-05 - 57ms/epoch - 2ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 6.1962e-05 - 62ms/epoch - 2ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 5.2433e-05 - 58ms/epoch - 2ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 8.9603e-05 - 58ms/epoch - 2ms/step
# Epoch 50/50
# 32/32 - 0s - loss: 4.0771e-05 - 61ms/epoch - 2ms/step
# The mean squared error (MSE) for the test data set is: 9.13811381906271e-05

# %% [markdown]
# Predict for new data

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import *

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

# Load the data we make to use to make a prediction
X = pd.read_csv("proposed_new_product.csv").values

# Make a prediction with the neural network
prediction =  model.predict(X)

# Grab just the first element of the first prediction (since that's the only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range back to dollars
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))
# Out:
# Epoch 1/50
# 32/32 - 1s - loss: 0.0280 - 963ms/epoch - 30ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 0.0027 - 58ms/epoch - 2ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 9.5036e-04 - 70ms/epoch - 2ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 5.0213e-04 - 65ms/epoch - 2ms/step
# Epoch 5/50
# 32/32 - 0s - loss: 3.2615e-04 - 68ms/epoch - 2ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 2.2443e-04 - 71ms/epoch - 2ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 1.7431e-04 - 63ms/epoch - 2ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 1.3631e-04 - 72ms/epoch - 2ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 1.1695e-04 - 68ms/epoch - 2ms/step
# Epoch 10/50
# 32/32 - 0s - loss: 9.8217e-05 - 71ms/epoch - 2ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 8.1304e-05 - 56ms/epoch - 2ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 7.3977e-05 - 65ms/epoch - 2ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 6.6491e-05 - 59ms/epoch - 2ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 5.9728e-05 - 54ms/epoch - 2ms/step
# Epoch 15/50
# 32/32 - 0s - loss: 5.4830e-05 - 68ms/epoch - 2ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 5.3936e-05 - 71ms/epoch - 2ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 4.7178e-05 - 91ms/epoch - 3ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 3.8728e-05 - 61ms/epoch - 2ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 3.7132e-05 - 63ms/epoch - 2ms/step
# Epoch 20/50
# 32/32 - 0s - loss: 3.7732e-05 - 52ms/epoch - 2ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 3.2944e-05 - 52ms/epoch - 2ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 4.3568e-05 - 57ms/epoch - 2ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 3.1861e-05 - 52ms/epoch - 2ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 3.0271e-05 - 59ms/epoch - 2ms/step
# Epoch 25/50
# 32/32 - 0s - loss: 2.6049e-05 - 63ms/epoch - 2ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 3.1998e-05 - 56ms/epoch - 2ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 3.2495e-05 - 64ms/epoch - 2ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 2.5952e-05 - 56ms/epoch - 2ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 2.9833e-05 - 53ms/epoch - 2ms/step
# Epoch 30/50
# 32/32 - 0s - loss: 2.6873e-05 - 63ms/epoch - 2ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 2.5643e-05 - 55ms/epoch - 2ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 2.2941e-05 - 53ms/epoch - 2ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 2.2227e-05 - 63ms/epoch - 2ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 2.7532e-05 - 65ms/epoch - 2ms/step
# Epoch 35/50
# 32/32 - 0s - loss: 3.0073e-05 - 59ms/epoch - 2ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 3.5037e-05 - 55ms/epoch - 2ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 2.2613e-05 - 59ms/epoch - 2ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 2.1504e-05 - 63ms/epoch - 2ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 3.2044e-05 - 65ms/epoch - 2ms/step
# Epoch 40/50
# 32/32 - 0s - loss: 2.3236e-05 - 58ms/epoch - 2ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 2.7383e-05 - 64ms/epoch - 2ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 2.5229e-05 - 53ms/epoch - 2ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 2.0690e-05 - 56ms/epoch - 2ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 2.1124e-05 - 71ms/epoch - 2ms/step
# Epoch 45/50
# 32/32 - 0s - loss: 1.9601e-05 - 59ms/epoch - 2ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 2.6997e-05 - 59ms/epoch - 2ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 3.1632e-05 - 62ms/epoch - 2ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 2.7756e-05 - 60ms/epoch - 2ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 2.0020e-05 - 78ms/epoch - 2ms/step
# Epoch 50/50
# 32/32 - 0s - loss: 2.7441e-05 - 59ms/epoch - 2ms/step
# The mean squared error (MSE) for the test data set is: 0.00011369645653758198
# 1/1 [==============================] - 0s 102ms/step
# Earnings Prediction for Proposed Product - $257332.72416899665

# %% [markdown]
# Save a model

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import *

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

# Save the model to disk

model.save("trained_model.h5")
print("Model saved to disk")
# Out:
# Epoch 1/50
# 32/32 - 2s - loss: 0.0081 - 2s/epoch - 50ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 9.2611e-04 - 55ms/epoch - 2ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 3.3850e-04 - 55ms/epoch - 2ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 1.9816e-04 - 61ms/epoch - 2ms/step
# Epoch 5/50
# 32/32 - 0s - loss: 1.3422e-04 - 59ms/epoch - 2ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 1.2462e-04 - 58ms/epoch - 2ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 8.8011e-05 - 57ms/epoch - 2ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 9.4842e-05 - 56ms/epoch - 2ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 6.4409e-05 - 68ms/epoch - 2ms/step
# Epoch 10/50
# 32/32 - 0s - loss: 5.3658e-05 - 63ms/epoch - 2ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 5.7073e-05 - 64ms/epoch - 2ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 4.6541e-05 - 54ms/epoch - 2ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 4.6634e-05 - 56ms/epoch - 2ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 3.9298e-05 - 77ms/epoch - 2ms/step
# Epoch 15/50
# 32/32 - 0s - loss: 3.9821e-05 - 60ms/epoch - 2ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 4.2968e-05 - 66ms/epoch - 2ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 2.9711e-05 - 55ms/epoch - 2ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 7.5765e-05 - 54ms/epoch - 2ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 5.8080e-05 - 65ms/epoch - 2ms/step
# Epoch 20/50
# 32/32 - 0s - loss: 4.8536e-05 - 53ms/epoch - 2ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 5.6260e-05 - 61ms/epoch - 2ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 5.6601e-05 - 59ms/epoch - 2ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 3.5748e-05 - 54ms/epoch - 2ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 4.0205e-05 - 96ms/epoch - 3ms/step
# Epoch 25/50
# 32/32 - 0s - loss: 4.6617e-05 - 84ms/epoch - 3ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 2.8169e-05 - 87ms/epoch - 3ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 2.7819e-05 - 80ms/epoch - 3ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 3.6581e-05 - 92ms/epoch - 3ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 2.3662e-05 - 91ms/epoch - 3ms/step
# Epoch 30/50
# 32/32 - 0s - loss: 2.3426e-05 - 79ms/epoch - 2ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 3.0012e-05 - 77ms/epoch - 2ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 2.6997e-05 - 76ms/epoch - 2ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 2.8244e-05 - 78ms/epoch - 2ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 3.0575e-05 - 77ms/epoch - 2ms/step
# Epoch 35/50
# 32/32 - 0s - loss: 5.1408e-05 - 75ms/epoch - 2ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 3.5919e-05 - 81ms/epoch - 3ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 3.4592e-05 - 91ms/epoch - 3ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 4.5258e-05 - 80ms/epoch - 2ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 5.5286e-05 - 87ms/epoch - 3ms/step
# Epoch 40/50
# 32/32 - 0s - loss: 3.3840e-05 - 114ms/epoch - 4ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 2.8022e-05 - 90ms/epoch - 3ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 2.6143e-05 - 88ms/epoch - 3ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 3.2397e-05 - 86ms/epoch - 3ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 6.7222e-05 - 87ms/epoch - 3ms/step
# Epoch 45/50
# 32/32 - 0s - loss: 4.2467e-05 - 86ms/epoch - 3ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 4.2322e-05 - 93ms/epoch - 3ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 3.1967e-05 - 78ms/epoch - 2ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 3.3690e-05 - 86ms/epoch - 3ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 5.0373e-05 - 89ms/epoch - 3ms/step
# Epoch 50/50
# 32/32 - 0s - loss: 6.8655e-05 - 96ms/epoch - 3ms/step
# The mean squared error (MSE) for the test data set is: 0.00010769199434434995
# Model saved to disk

# %% [markdown]
# Load the save model

# %%
import pandas as pd
from keras.models import load_model

model = load_model("trained_model.h5")

X = pd.read_csv("proposed_new_product.csv").values
prediction = model.predict(X)

# Grab just the first element of the first prediction (since we only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range back to dollars
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))
# Out:
# 1/1 [==============================] - 0s 127ms/step
# Earnings Prediction for Proposed Product - $271225.2757116407
